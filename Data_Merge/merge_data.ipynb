# %%
# Load packages
import pandas as pd 
import time
import re

# %% [markdown]
# ## Importing Datasets

# %%
google_play_store = pd.read_csv(r'C:\Users\User\TSAP-UberEats-1\Jay_WebScraping\Final_Google_Play_Store\Google_Playstore.csv')
google_play_store.head()
# Out:
#                                               review              date  \
# 0  Edit: they brought the feature back! Used to b...  January 18, 2024
# 1  Lately it's very common to wait over 2 hours f...  January 20, 2024
# 2  Very disappointed in this app. I've used it fo...  January 19, 2024
# 3  Fairly easy to use but trying to find out what...  January 20, 2024
# 4  Don't like the fact u can't get a refund unles...  January 19, 2024
#
#                              stars             name             source
# 0  Rated 5 stars out of five stars     Rufus Wright  Google Play Store
# 1  Rated 1 stars out of five stars        Bastian H  Google Play Store
# 2  Rated 1 stars out of five stars         Kristi B  Google Play Store
# 3  Rated 2 stars out of five stars        broomee c  Google Play Store
# 4  Rated 4 stars out of five stars  Teresa Anderson  Google Play Store

# %%
hellopeter = pd.read_csv(r'C:\Users\User\TSAP-UberEats-1\Jay_WebScraping\Hellopeter\ubereats_hellopeter.csv')
hellopeter.head()
# Out:
#                                               review                  date  \
# 0  I have tried to order from Uber eats 2 times n...  21 Jan 2024 at 21:56
# 1  Uber eats is taking my money and I'm not recei...  21 Jan 2024 at 13:22
# 2  Twice in one week I have placed an order on Ub...  20 Jan 2024 at 19:35
# 3  I'm disappointed about Uber eats I oder pizza ...  20 Jan 2024 at 13:24
# 4  Ubereats is a dysfunctional company. Quick to ...  20 Jan 2024 at 07:07
#
#    stars            name      source  \
# 0      1      Duduzile S  hellopeter
# 1      1         Abram M  hellopeter
# 2      1  Mandi-Lee Maia  hellopeter
# 3      1           Jan S  hellopeter
# 4      1          pierre  hellopeter
#
#                                           title
# 0                              Horrible service
# 1                           Uber eats is a ****
# 2                                      Ubereats
# 3                       **** Uber eats ****mers
# ...

# %% [markdown]
# ### Merging Datsets

# %%
result = pd.concat([google_play_store, hellopeter])

# %%
result
# Out:
#                                                review                  date  \
# 0   Edit: they brought the feature back! Used to b...      January 18, 2024
# 1   Lately it's very common to wait over 2 hours f...      January 20, 2024
# 2   Very disappointed in this app. I've used it fo...      January 19, 2024
# 3   Fairly easy to use but trying to find out what...      January 20, 2024
# 4   Don't like the fact u can't get a refund unles...      January 19, 2024
# ..                                                ...                   ...
# 6   I ordered a pizza and a 2lt Cream Soda from Pi...  19 Jan 2024 at 14:54
# 7   I placed an order with Pedros Umhlanga via the...  19 Jan 2024 at 12:12
# 8   Do not ever use the Uber Eats for Grocery, unl...  19 Jan 2024 at 11:39
# 9   On the 12the Jan evening i placed an order of ...  18 Jan 2024 at 20:33
# 10  I ordered and paid online for food fishways.it...  18 Jan 2024 at 10:27
#
# ...
